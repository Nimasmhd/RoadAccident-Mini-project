# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
data = pd.read_excel("Dataset2severity.xlsx")
data.head()
# Out:
#    Year       Date      Time  longitude  latitude      Road Type Weather  \
# 0  2019 2019-01-12  19:30:00  80.501992  8.864614  Main Junction   Sunny
# 1  2019 2019-01-13  19:15:00  80.511604  8.926673  Main Junction   Sunny
# 2  2019 2019-01-24  10:45:00  80.493580  8.820302      Main Road   Sunny
# 3  2019 2019-01-26  13:30:00  80.521348  8.952927      Main Road   Sunny
# 4  2019 2019-01-31  19:10:00  80.490806  8.805887      Main Road   Sunny
#
#   Gender                Vehicle   Severity
# 0   male         Car,Motorcycle   Low_Risk
# 1   male                    Van   Low_Risk
# 2   male            Tractor,Bus  High_Risk
# 3   male  Motorcycle,Motorcycle  High_Risk
# 4   male        Motorcycle, Car  High_Risk

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433 entries, 0 to 432
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       433 non-null    int64
#  1   Date       433 non-null    datetime64[ns]
#  2   Time       433 non-null    object
#  3   longitude  433 non-null    float64
#  4   latitude   433 non-null    float64
#  5   Road Type  433 non-null    object
#  6   Weather    433 non-null    object
#  7   Gender     433 non-null    object
#  8   Vehicle    433 non-null    object
#  9   Severity   433 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 34.0+ KB

# %%
data.describe(include='all')
# Out:
#                Year                           Date      Time   longitude  \
# count    433.000000                            433       433  433.000000
# unique          NaN                            NaN       129         NaN
# top             NaN                            NaN  19:00:00         NaN
# freq            NaN                            NaN        15         NaN
# mean    2021.150115  2021-08-14 15:07:53.903002368       NaN   80.500461
# min     2019.000000            2019-01-03 00:00:00       NaN   80.478174
# 25%     2019.000000            2019-12-09 00:00:00       NaN   80.488626
# 50%     2021.000000            2021-08-06 00:00:00       NaN   80.496894
# 75%     2023.000000            2023-02-21 00:00:00       NaN   80.511604
# max     2024.000000            2024-12-17 00:00:00       NaN   80.526532
# std        1.782920                            NaN       NaN    0.013938
#
#           latitude  Road Type Weather Gender     Vehicle   Severity
# count   433.000000        433     433    433         433        433
# unique         NaN          4       4      4         120          2
# top            NaN  Main Road   Sunny   male  Motorcycle  High_Risk
# freq           NaN        304     330    374          79        249
# mean      8.813231        NaN     NaN    NaN         NaN        NaN
# min       8.673499        NaN     NaN    NaN         NaN        NaN
# 25%       8.746691        NaN     NaN    NaN         NaN        NaN
# 50%       8.764160        NaN     NaN    NaN         NaN        NaN
# 75%       8.926673        NaN     NaN    NaN         NaN        NaN
# max       8.970074        NaN     NaN    NaN         NaN        NaN
# std       0.091889        NaN     NaN    NaN         NaN        NaN

# %%
data.isnull().sum()
# Out:
# Year         0
# Date         0
# Time         0
# longitude    0
# latitude     0
# Road Type    0
# Weather      0
# Gender       0
# Vehicle      0
# Severity     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Severity", data=data)
plt.title("Accident Severity Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Weather", data=data)
plt.title("Weather Conditions")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Road Type", data=data)
plt.title("Road Type Distribution")
plt.xticks(rotation=45)
plt.show()

# %%
data["Hour"] = pd.to_datetime(data["Time"], format="%H:%M:%S").dt.hour
data["Month"] = pd.to_datetime(data["Date"]).dt.month

data.drop(["Date", "Time"], axis=1, inplace=True)

# %%
label_encoders = {}

categorical_cols = ["Road Type", "Weather", "Gender", "Vehicle", "Severity"]

for col in categorical_cols:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    label_encoders[col] = le

data.head()
# Out:
#    Year  longitude  latitude  Road Type  Weather  Gender  Vehicle  Severity  \
# 0  2019  80.501992  8.864614          2        3       2       30         1
# 1  2019  80.511604  8.926673          2        3       2       80         1
# 2  2019  80.493580  8.820302          3        3       2       78         0
# 3  2019  80.521348  8.952927          3        3       2       63         0
# 4  2019  80.490806  8.805887          3        3       2       55         0
#
#    Hour  Month
# 0    19      1
# 1    19      1
# 2    10      1
# 3    13      1
# 4    19      1

# %%
X = data.drop("Severity", axis=1)
y = data["Severity"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

print("Training samples:", X_train.shape[0])
print("Testing samples:", X_test.shape[0])
# Out:
# Training samples: 346
# Testing samples: 87

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

dt_model = DecisionTreeClassifier(
    criterion="gini",
    max_depth=6,
    random_state=42
)

dt_model.fit(X_train, y_train)

y_pred_dt = dt_model.predict(X_test)

print("Decision Tree Results")
print(confusion_matrix(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Results
# [[35 12]
#  [21 19]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.74      0.68        47
#            1       0.61      0.47      0.54        40
#
#     accuracy                           0.62        87
#    macro avg       0.62      0.61      0.61        87
# weighted avg       0.62      0.62      0.61        87

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel="rbf", probability=True)
svm_model.fit(X_train, y_train)

y_pred_svm = svm_model.predict(X_test)

print("SVM Results")
print(confusion_matrix(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))
# Out:
# SVM Results
# [[36 11]
#  [30 10]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.77      0.64        47
#            1       0.48      0.25      0.33        40
#
#     accuracy                           0.53        87
#    macro avg       0.51      0.51      0.48        87
# weighted avg       0.51      0.53      0.49        87

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors=7)
knn_model.fit(X_train, y_train)

y_pred_knn = knn_model.predict(X_test)

print("KNN Results")
print(confusion_matrix(y_test, y_pred_knn))
print(classification_report(y_test, y_pred_knn))
# Out:
# KNN Results
# [[33 14]
#  [21 19]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.70      0.65        47
#            1       0.58      0.47      0.52        40
#
#     accuracy                           0.60        87
#    macro avg       0.59      0.59      0.59        87
# weighted avg       0.59      0.60      0.59        87

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9425287356321839

# %%
print("Classification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95        47
#            1       0.97      0.90      0.94        40
#
#     accuracy                           0.94        87
#    macro avg       0.95      0.94      0.94        87
# weighted avg       0.94      0.94      0.94        87

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
feature_names = X.columns
feature_names
# Out:
# Index(['Year', 'longitude', 'latitude', 'Road Type', 'Weather', 'Gender',
#        'Vehicle', 'Hour', 'Month'],
#       dtype='object')

# %%
new_data = pd.DataFrame({
    "Year": [2024],
    "longitude": [80.62],
    "latitude": [8.78],
    "Road Type": [1],
    "Weather": [0],
    "Gender": [1],
    "Vehicle": [2],
    "Hour": [21],
    "Month": [5]

})
#0 - High_Risk, 0 - Low_Risk


new_data_scaled = scaler.transform(new_data)
prediction = model.predict(new_data_scaled)

print("Predicted Accident Severity:", prediction[0])
# Out:
# Predicted Accident Severity: 1

# %%
import pickle

# model
with open("road_accident_model.pkl", "wb") as f:
    pickle.dump(model, f)

# scaler
with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

# encoders
with open("label_encoders.pkl", "wb") as f:
    pickle.dump(label_encoders, f)
